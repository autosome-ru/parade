# %%
from flowmatching import CNNModel, FlowMatcher, BetaTimeSampler, UTRGenerator
from fm_dataset import create_datasets, collate_dict_batch

# %%
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

import pytorch_lightning as pl
pl.seed_everything(42)
# Out:
# Global seed set to 42

# %%
utr_type = 5
seq_length = 50 if utr_type == 5 else 240

table_path = f'../../predictor/regression_multiple/UTR{utr_type}_zscores_replicateagg.csv'

num_cell_types = 5 if utr_type == 5 else 6

device = 'cuda:1'

# %%
train_dataset, _, _ = create_datasets(
    utr_type=utr_type,
    table_path=table_path,
)
# Out:
# Loading UTR data...:   0%|          | 0/17288 [00:00<?, ?it/s]
# Loading UTR data...:   0%|          | 0/2161 [00:00<?, ?it/s]
# Loading UTR data...:   0%|          | 0/2160 [00:00<?, ?it/s]

# %%
loader = DataLoader(
    train_dataset,
    batch_size=512,
    shuffle=True,
    collate_fn=collate_dict_batch
)

# %%
model = CNNModel(
    input_size=4,
    hidden_dim=512,
    num_cnn_stacks=2,
    dropout=0.1,
    num_cell_types=num_cell_types,
)

sum(p.numel() for p in model.parameters()) + sum(p.numel() for p in model.buffers())
# Out:
# 32320004

# %%
flow_matcher = FlowMatcher(
    model=model,
    seq_length=seq_length,
    prior_pseudocount=1,
    flow_temp=1.0,
    cls_free_noclass_ratio=0.1,
    time_sampler=BetaTimeSampler(alpha=1, beta=3.3),
    device=device,
)

# %%
loss_history = flow_matcher.run_training(
    dataloader=loader,
    max_lr=1e-3,
    num_epochs=6
)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/169 [00:00<?, ?it/s]
#   0%|          | 0/169 [00:00<?, ?it/s]
#   0%|          | 0/169 [00:00<?, ?it/s]
#   0%|          | 0/169 [00:00<?, ?it/s]
#   0%|          | 0/169 [00:00<?, ?it/s]
#   0%|          | 0/169 [00:00<?, ?it/s]

# %%
plt.plot(loss_history)

# %%
generated, x0 = flow_matcher.sample(
    num_samples=10,
    cell_type=0,
    num_integration_steps=10,
    guidance_scale=6,
    expression=2.3,
    verbose=True
)

# %%
scorer = UTRGenerator(
    utr_type=utr_type,
    device='cuda:0'
)

gen_kwargs = {
    'num_integration_steps': 10,
    'guidance_scale': 30,
}

metrics, seq_table = scorer.score_generator(
    generator=flow_matcher,
    generation_method_name='sample',
    total_samples=1024 * 1000,
    batch_size=1024,
    **gen_kwargs
)
metrics
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
seq_table.to_csv(f'lfm_utr{utr_type}.csv')
