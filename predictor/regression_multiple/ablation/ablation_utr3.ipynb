# %%
import os
import sys
import importlib
import math
import time

import itertools
from collections import defaultdict

import numpy as np
import pandas as pd
import scipy.stats as ss
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm as tqdm_auto
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import pytorch_lightning as pl

from IPython.display import clear_output

# %%
sys.path.append("../../model")
import utrdata_cl as utrdata
from legnet import LegNetClassifier
from pl_regressor import RNARegressor

# %%
UTR_TYPE = "utr3"
SEQSIZE = 50 if UTR_TYPE == "utr5" else 240

# %% [markdown]
# ## Loading data

# %%
from ablation_utils import load_data, launch_model

# %%
splits = load_data(utr_type=UTR_TYPE, prefix="..")

batch_size = 1024
steps_per_epoch = max(1, splits["train"].shape[0] // batch_size)
num_workers = 32

# %%
def parameter_ablation(
    model_name: str,
    parameter_update: dict,
):
    checked = {
        "seed": range(0, 30),
        "features": [
            # ("sequence", "revcomp", "intensity", "positional", "conditions"),
            ("sequence", "positional", "conditions"),
        ],
        "augment_dict": [
            dict(
                extend_left=0,
                extend_right=0,
                shift_left=0,
                shift_right=0,
                revcomp=False,
            ),
        ],
        "epochs": [10],
        "predict_cols": [['diff', 'mass_center']],
    }
    checked.update(parameter_update)

    METRICS = list()

    for subset in itertools.product(
        *checked.values()
    ):
        PARAMS = dict(zip(checked.keys(), subset))
        AUGMENT_KEY = any(PARAMS["augment_dict"].values())
        AUGMENT_TEST_TIME = AUGMENT_KEY

        metrics = launch_model(
            model_name=model_name,
            seed=PARAMS["seed"],
            train_ds_kws=dict(
                predict_cols=PARAMS["predict_cols"],
                construct_type=UTR_TYPE,
                features=PARAMS["features"],  # ("sequence", "conditions", "positional", "revcomp")
                augment=AUGMENT_KEY,
                augment_test_time=False,
                augment_kws=PARAMS["augment_dict"],
            ),
            val_ds_kws=dict(
                predict_cols=PARAMS["predict_cols"],
                construct_type=UTR_TYPE,
                features=PARAMS["features"],  # ("sequence", "conditions", "positional", "revcomp")
                augment=False,
                augment_test_time=AUGMENT_TEST_TIME,
                augment_kws=PARAMS["augment_dict"],
            ),
            model_class=LegNetClassifier,
            model_kws=dict(
                seqsize=SEQSIZE,
                ks=3,
                out_channels=PARAMS["predict_cols"].__len__(),
                conv_sizes=(128, 64, 64, 32, 32),
                mapper_size=256,
                linear_sizes=None,
                use_max_pooling=False,
                final_activation=nn.Identity
            ),
            criterion_class=nn.MSELoss,
            criterion_kws=dict(),
            optimizer_class=torch.optim.AdamW,
            optimizer_kws=dict(
                # lr=0.01,
                weight_decay=0.1,
            ),
            lr_scheduler_class=torch.optim.lr_scheduler.OneCycleLR,
            lr_scheduler_kws=dict(
                max_lr=0.01,
                steps_per_epoch=steps_per_epoch,
                epochs=PARAMS["epochs"],
                pct_start=0.3,
                three_phase=False,
                cycle_momentum=True,
            ),
            test_time_validation=AUGMENT_TEST_TIME,
            epochs=PARAMS["epochs"],
        )
        METRICS.append(metrics)
    return METRICS

# %% [markdown]
# ## Launching ablation

# %%
ablation_tests = {
    "NoChanges": {},
    "RemovedDiff": {
        "predict_cols": [['mass_center']],
    },
    "RemovedPositionalEncoding": {
        "features": [
            ("sequence", "conditions"),
        ],
    },
    "RemovedDiffAndPositionalEncoding": {
        "predict_cols": [['mass_center']],
        "features": [
            ("sequence", "conditions"),
        ],
    },
}

ablation_metrics = list()
for test_name, update_dict in ablation_tests.items():
    iter_metrics = parameter_ablation(model_name=test_name, parameter_update=update_dict)
    ablation_metrics.extend(iter_metrics)
# Out:
# Global seed set to 0
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Missing logger folder: tb_logs/NoChanges
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | model     | LegNetClassifier | 269 K
# 1 | criterion | MSELoss          | 0
# -----------------------------------------------
# 269 K     Trainable params
# 0         Non-trainable params
# 269 K     Total params
# 1.076     Total estimated model params size (MB)
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2653627/1580175075.py", line 21, in <module>
#   File "/tmp/ipykernel_2653627/2564850090.py", line 34, in parameter_ablation
#   File "/tmp/ipykernel_2653627/1165118084.py", line 100, in launch_model
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 520, in fit
#     call._call_and_handle_interrupt(
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py", line 67, in _call_and_handle_interrupt
#     logger.finalize("failed")
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py", line 27, in wrapped_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loggers/tensorboard.py", line 221, in finalize
#     super().finalize(status)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py", line 27, in wrapped_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_fabric/loggers/tensorboard.py", line 277, in finalize
#     self.experiment.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 1200, in flush
#     writer.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 150, in flush
#     self.event_writer.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 125, in flush
#     self._async_writer.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 186, in flush
#     self._check_worker_status()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 212, in _check_worker_status
#     raise exception
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py", line 44, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 559, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 935, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 978, in _run_stage
#     self.fit_loop.run()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py", line 201, in run
#     self.advance()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py", line 354, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py", line 133, in run
#     self.advance(data_fetcher)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py", line 239, in advance
#     trainer._logger_connector.update_train_step_metrics()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py", line 154, in update_train_step_metrics
#     self.log_metrics(self.metrics["log"])
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py", line 109, in log_metrics
#     logger.save()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py", line 27, in wrapped_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loggers/tensorboard.py", line 209, in save
#     super().save()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py", line 27, in wrapped_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_fabric/loggers/tensorboard.py", line 272, in save
#     self.experiment.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 1200, in flush
#     writer.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py", line 150, in flush
#     self.event_writer.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 125, in flush
#     self._async_writer.flush()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 194, in flush
#     self._check_worker_status()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 212, in _check_worker_status
#     raise exception
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 244, in run
#     self._run()
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py", line 275, in _run
#     self._record_writer.write(data)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/record_writer.py", line 40, in write
#     self._writer.write(header + header_crc + data + footer_crc)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py", line 773, in write
#     self.fs.append(self.filename, file_content, self.binary_mode)
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py", line 167, in append
#     self._write(filename, file_content, "ab" if binary_mode else "a")
#   File "/home/arsen_l/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py", line 171, in _write
#     with io.open(filename, mode, encoding=encoding) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: b'tb_logs/NoChanges/version_0/events.out.tfevents.1768326685.Sydney.2653627.0'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 21
#      19 ablation_metrics = list()
#      20 for test_name, update_dict in ablation_tests.items():
# ---> 21     iter_metrics = parameter_ablation(model_name=test_name, parameter_update=update_dict)
#      22     ablation_metrics.extend(iter_metrics)
#
# Cell In[8], line 34, in parameter_ablation(model_name, parameter_update)
#      31     AUGMENT_KEY = any(PARAMS["augment_dict"].values())
#      32     AUGMENT_TEST_TIME = AUGMENT_KEY
# ---> 34     metrics = launch_model(
#      35         model_name=model_name,
#      36         seed=PARAMS["seed"],
#      37         train_ds_kws=dict(
#      38             predict_cols=PARAMS["predict_cols"],
#      39             construct_type=UTR_TYPE,
#      40             features=PARAMS["features"],  # ("sequence", "conditions", "positional", "revcomp")
#      41             augment=AUGMENT_KEY,
#      42             augment_test_time=False,
#      43             augment_kws=PARAMS["augment_dict"],
#      44         ),
#      45         val_ds_kws=dict(
#      46             predict_cols=PARAMS["predict_cols"],
#      47             construct_type=UTR_TYPE,
#      48             features=PARAMS["features"],  # ("sequence", "conditions", "positional", "revcomp")
#      49             augment=False,
#      50             augment_test_time=AUGMENT_TEST_TIME,
#      51             augment_kws=PARAMS["augment_dict"],
#      52         ),
#      53         model_class=LegNetClassifier,
#      54         model_kws=dict(
#      55             seqsize=SEQSIZE,
#      56             ks=3,
#      57             out_channels=PARAMS["predict_cols"].__len__(),
#      58             conv_sizes=(128, 64, 64, 32, 32),
#      59             mapper_size=256,
#      60             linear_sizes=None,
#      61             use_max_pooling=False,
#      62             final_activation=nn.Identity
#      63         ),
#      64         criterion_class=nn.MSELoss,
#      65         criterion_kws=dict(),
#      66         optimizer_class=torch.optim.AdamW,
#      67         optimizer_kws=dict(
#      68             # lr=0.01,
#      69             weight_decay=0.1,
#      70         ),
#      71         lr_scheduler_class=torch.optim.lr_scheduler.OneCycleLR,
#      72         lr_scheduler_kws=dict(
#      73             max_lr=0.01,
#      74             steps_per_epoch=steps_per_epoch,
#      75             epochs=PARAMS["epochs"],
#      76             pct_start=0.3,
#      77             three_phase=False,
#      78             cycle_momentum=True,
#      79         ),
#      80         test_time_validation=AUGMENT_TEST_TIME,
#      81         epochs=PARAMS["epochs"],
#      82     )
#      83     METRICS.append(metrics)
#      84 return METRICS
#
# Cell In[7], line 100, in launch_model(model_name, seed, train_ds_kws, val_ds_kws, model_class, model_kws, criterion_class, criterion_kws, optimizer_class, optimizer_kws, lr_scheduler_class, lr_scheduler_kws, test_time_validation, epochs)
#      88 logger = pl.loggers.tensorboard.TensorBoardLogger("tb_logs", name=model.model_name)
#      89 trainer = pl.Trainer(
#      90     callbacks=[checkpoint_callback, progressbar_callback],
#      91     logger=logger,
#    (...)
#      98     # gradient_clip_algorithm="norm",
#      99 )
# --> 100 trainer.fit(model=model, train_dataloaders=dl_train, val_dataloaders=dl_val)
#     101 best_model = RNARegressor.load_from_checkpoint(checkpoint_callback.best_model_path)
#     103 prediction = trainer.predict(model=best_model, dataloaders=dl_test)
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:520, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     518 model = _maybe_unwrap_optimized(model)
#     519 self.strategy._lightning_module = model
# --> 520 call._call_and_handle_interrupt(
#     521     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     522 )
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:67, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      65 trainer.strategy.on_exception(exception)
#      66 for logger in trainer.loggers:
# ---> 67     logger.finalize("failed")
#      68 trainer._teardown()
#      69 # teardown might access the stage so we reset it after
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py:27, in rank_zero_only.<locals>.wrapped_fn(*args, **kwargs)
#      25     raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      26 if rank == 0:
# ---> 27     return fn(*args, **kwargs)
#      28 return None
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loggers/tensorboard.py:221, in TensorBoardLogger.finalize(self, status)
#     219 @rank_zero_only
#     220 def finalize(self, status: str) -> None:
# --> 221     super().finalize(status)
#     222     if status == "success":
#     223         # saving hparams happens independent of experiment manager
#     224         self.save()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py:27, in rank_zero_only.<locals>.wrapped_fn(*args, **kwargs)
#      25     raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      26 if rank == 0:
# ---> 27     return fn(*args, **kwargs)
#      28 return None
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_fabric/loggers/tensorboard.py:277, in TensorBoardLogger.finalize(self, status)
#     274 @rank_zero_only
#     275 def finalize(self, status: str) -> None:
#     276     if self._experiment is not None:
# --> 277         self.experiment.flush()
#     278         self.experiment.close()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py:1200, in SummaryWriter.flush(self)
#    1198     return
#    1199 for writer in self.all_writers.values():
# -> 1200     writer.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py:150, in FileWriter.flush(self)
#     145 def flush(self):
#     146     """Flushes the event file to disk.
#     147     Call this method to make sure that all pending events have been written to
#     148     disk.
#     149     """
# --> 150     self.event_writer.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:125, in EventFileWriter.flush(self)
#     119 def flush(self):
#     120     """Flushes the event file to disk.
#     121
#     122     Call this method to make sure that all pending events have been
#     123     written to disk.
#     124     """
# --> 125     self._async_writer.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:186, in _AsyncWriter.flush(self)
#     181 """Write all the enqueued bytestring before this flush call to disk.
#     182
#     183 Block until all the above bytestring are written.
#     184 """
#     185 with self._lock:
# --> 186     self._check_worker_status()
#     187     if self._closed:
#     188         raise IOError("Writer is closed")
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:212, in _AsyncWriter._check_worker_status(self)
#     210 exception = self._worker.exception
#     211 if exception is not None:
# --> 212     raise exception
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#      43     else:
# ---> 44         return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:559, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     549 self._data_connector.attach_data(
#     550     model, train_dataloaders=train_dataloaders, val_dataloaders=val_dataloaders, datamodule=datamodule
#     551 )
#     553 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     554     self.state.fn,
#     555     ckpt_path,
#     556     model_provided=True,
#     557     model_connected=self.lightning_module is not None,
#     558 )
# --> 559 self._run(model, ckpt_path=ckpt_path)
#     561 assert self.state.stopped
#     562 self.training = False
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:935, in Trainer._run(self, model, ckpt_path)
#     930 self._signal_connector.register_signal_handlers()
#     932 # ----------------------------
#     933 # RUN THE TRAINER
#     934 # ----------------------------
# --> 935 results = self._run_stage()
#     937 # ----------------------------
#     938 # POST-Training CLEAN UP
#     939 # ----------------------------
#     940 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:978, in Trainer._run_stage(self)
#     976         self._run_sanity_check()
#     977     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# --> 978         self.fit_loop.run()
#     979     return None
#     980 raise RuntimeError(f"Unexpected state {self.state}")
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:201, in _FitLoop.run(self)
#     199 try:
#     200     self.on_advance_start()
# --> 201     self.advance()
#     202     self.on_advance_end()
#     203     self._restarting = False
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:354, in _FitLoop.advance(self)
#     352 self._data_fetcher.setup(combined_loader)
#     353 with self.trainer.profiler.profile("run_training_epoch"):
# --> 354     self.epoch_loop.run(self._data_fetcher)
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py:133, in _TrainingEpochLoop.run(self, data_fetcher)
#     131 while not self.done:
#     132     try:
# --> 133         self.advance(data_fetcher)
#     134         self.on_advance_end()
#     135         self._restarting = False
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py:239, in _TrainingEpochLoop.advance(self, data_fetcher)
#     234 self.batch_progress.increment_completed()
#     236 # -----------------------------------------
#     237 # SAVE METRICS TO LOGGERS AND PROGRESS_BAR
#     238 # -----------------------------------------
# --> 239 trainer._logger_connector.update_train_step_metrics()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:154, in _LoggerConnector.update_train_step_metrics(self)
#     152 assert not self._epoch_end_reached
#     153 if self.should_update_logs or self.trainer.fast_dev_run:
# --> 154     self.log_metrics(self.metrics["log"])
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:109, in _LoggerConnector.log_metrics(self, metrics, step)
#     107 for logger in self.trainer.loggers:
#     108     logger.log_metrics(metrics=scalar_metrics, step=step)
# --> 109     logger.save()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py:27, in rank_zero_only.<locals>.wrapped_fn(*args, **kwargs)
#      25     raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      26 if rank == 0:
# ---> 27     return fn(*args, **kwargs)
#      28 return None
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/pytorch_lightning/loggers/tensorboard.py:209, in TensorBoardLogger.save(self)
#     207 @rank_zero_only
#     208 def save(self) -> None:
# --> 209     super().save()
#     210     dir_path = self.log_dir
#     212     # prepare the file path
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_utilities/core/rank_zero.py:27, in rank_zero_only.<locals>.wrapped_fn(*args, **kwargs)
#      25     raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      26 if rank == 0:
# ---> 27     return fn(*args, **kwargs)
#      28 return None
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/lightning_fabric/loggers/tensorboard.py:272, in TensorBoardLogger.save(self)
#     270 @rank_zero_only
#     271 def save(self) -> None:
# --> 272     self.experiment.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py:1200, in SummaryWriter.flush(self)
#    1198     return
#    1199 for writer in self.all_writers.values():
# -> 1200     writer.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/torch/utils/tensorboard/writer.py:150, in FileWriter.flush(self)
#     145 def flush(self):
#     146     """Flushes the event file to disk.
#     147     Call this method to make sure that all pending events have been written to
#     148     disk.
#     149     """
# --> 150     self.event_writer.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:125, in EventFileWriter.flush(self)
#     119 def flush(self):
#     120     """Flushes the event file to disk.
#     121
#     122     Call this method to make sure that all pending events have been
#     123     written to disk.
#     124     """
# --> 125     self._async_writer.flush()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:194, in _AsyncWriter.flush(self)
#     190 self._writer.flush()
#     191 # Check the status again in case the background worker thread has
#     192 # failed in the meantime to avoid waiting until the next call to
#     193 # surface the error.
# --> 194 self._check_worker_status()
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:212, in _AsyncWriter._check_worker_status(self)
#     210 exception = self._worker.exception
#     211 if exception is not None:
# --> 212     raise exception
#
# File ~/.miniconda3/envs/ml/lib/python3.11/threading.py:1038, in Thread._bootstrap_inner(self)
#    1035     _sys.setprofile(_profile_hook)
#    1037 try:
# -> 1038     self.run()
#    1039 except:
#    1040     self._invoke_excepthook(self)
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:244, in _AsyncWriterThread.run(self)
#     242 def run(self):
#     243     try:
# --> 244         self._run()
#     245     except Exception as ex:
#     246         self.exception = ex
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/event_file_writer.py:275, in _AsyncWriterThread._run(self)
#     273     if data is self._shutdown_signal:
#     274         return
# --> 275     self._record_writer.write(data)
#     276     self._has_pending_data = True
#     277 except queue.Empty:
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/summary/writer/record_writer.py:40, in RecordWriter.write(self, data)
#      38 header_crc = struct.pack("<I", masked_crc32c(header))
#      39 footer_crc = struct.pack("<I", masked_crc32c(data))
# ---> 40 self._writer.write(header + header_crc + data + footer_crc)
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py:773, in GFile.write(self, file_content)
#     769         self.write_started = True
#     771     else:
#     772         # append the later chunks
# --> 773         self.fs.append(self.filename, file_content, self.binary_mode)
#     774 else:
#     775     # add to temp file, but wait for flush to write to final filesystem
#     776     if self.write_temp is None:
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py:167, in LocalFileSystem.append(self, filename, file_content, binary_mode)
#     159 def append(self, filename, file_content, binary_mode=False):
#     160     """Append string file contents to a file.
#     161
#     162     Args:
#    (...)
#     165         binary_mode: bool, write as binary if True, otherwise text
#     166     """
# --> 167     self._write(filename, file_content, "ab" if binary_mode else "a")
#
# File ~/.miniconda3/envs/ml/lib/python3.11/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py:171, in LocalFileSystem._write(self, filename, file_content, mode)
#     169 def _write(self, filename, file_content, mode):
#     170     encoding = None if "b" in mode else "utf8"
# --> 171     with io.open(filename, mode, encoding=encoding) as f:
#     172         compatify = compat.as_bytes if "b" in mode else compat.as_text
#     173         f.write(compatify(file_content))
#
# FileNotFoundError: [Errno 2] No such file or directory: b'tb_logs/NoChanges/version_0/events.out.tfevents.1768326685.Sydney.2653627.0'

# %%
import json

with open(f"{UTR_TYPE}_ablation.json", "wt") as handle:
    json.dump(ablation_metrics, handle)

# %% [markdown]
# ---
